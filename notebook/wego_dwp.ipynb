# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Access raw dataframe
headway_data = pd.read_csv("../data/Headway Data.csv.txt")
headway_data.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
# 4    120211101             1      76447168  2021-11-01          50
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# 0        1704      2088   297750            0          TO DOWNTOWN  ...
# 1        1704      2088   297750            0          TO DOWNTOWN  ...
# 2        1704      2088   297750            0          TO DOWNTOWN  ...
# 3        1704      2088   297749            0          TO DOWNTOWN  ...
# 4        1704      2088   297749            0          TO DOWNTOWN  ...
#
#   ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# ...

# %%
# Display columns in dataframe
headway_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1981715 entries, 0 to 1981714
# Data columns (total 30 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   CALENDAR_ID                int64
#  1   SERVICE_ABBR               int64
#  2   ADHERENCE_ID               int64
#  3   DATE                       object
#  4   ROUTE_ABBR                 int64
#  5   BLOCK_ABBR                 int64
#  6   OPERATOR                   int64
#  7   TRIP_ID                    int64
#  8   OVERLOAD_ID                int64
#  9   ROUTE_DIRECTION_NAME       object
#  10  TIME_POINT_ABBR            object
#  11  ROUTE_STOP_SEQUENCE        float64
#  12  TRIP_EDGE                  int64
#  13  LATITUDE                   float64
#  14  LONGITUDE                  float64
#  15  SCHEDULED_TIME             object
#  16  ACTUAL_ARRIVAL_TIME        object
#  17  ACTUAL_DEPARTURE_TIME      object
#  18  ADHERENCE                  float64
# ...

# %%
# Display columns and NA's in dataframe 
headway_data.isna().sum()
# Out:
# CALENDAR_ID                       0
# SERVICE_ABBR                      0
# ADHERENCE_ID                      0
# DATE                              0
# ROUTE_ABBR                        0
# BLOCK_ABBR                        0
# OPERATOR                          0
# TRIP_ID                           0
# OVERLOAD_ID                       0
# ROUTE_DIRECTION_NAME              0
# TIME_POINT_ABBR                   0
# ROUTE_STOP_SEQUENCE              41
# TRIP_EDGE                         0
# LATITUDE                          0
# LONGITUDE                         0
# SCHEDULED_TIME                    0
# ACTUAL_ARRIVAL_TIME           54383
# ACTUAL_DEPARTURE_TIME         54430
# ADHERENCE                     54430
# SCHEDULED_HDWY               432294
# ACTUAL_HDWY                  473824
# HDWY_DEV                     474368
# ADJUSTED_EARLY_COUNT              0
# ADJUSTED_LATE_COUNT               0
# ADJUSTED_ONTIME_COUNT             0
# STOP_CANCELLED                    0
# ...

# %%
# Access raw dataframe
bna_2022 = pd.read_csv("../data/bna_2022.csv")
bna_2022.head()
# Out:
#     key        class  expire_time_gmt obs_id   obs_name  valid_time_gmt  \
# 0  KBNA  observation       1641027180   KBNA  Nashville      1641019980
# 1  KBNA  observation       1641030780   KBNA  Nashville      1641023580
# 2  KBNA  observation       1641034380   KBNA  Nashville      1641027180
# 3  KBNA  observation       1641037980   KBNA  Nashville      1641030780
# 4  KBNA  observation       1641041580   KBNA  Nashville      1641034380
#
#   day_ind  temp  wx_icon  icon_extd  ... clds  water_temp primary_wave_period  \
# 0       N    71       26       2600  ...  OVC         NaN                 NaN
# 1       N    72       26       2600  ...  OVC         NaN                 NaN
# 2       N    73       26       2600  ...  OVC         NaN                 NaN
# 3       N    73       26       2600  ...  OVC         NaN                 NaN
# 4       N    73       26       2600  ...  OVC         NaN                 NaN
#
# ...

# %%
# Display columns and NA's in dataframe
bna_2022.isna().sum()
# Out:
# key                             0
# class                           0
# expire_time_gmt                 0
# obs_id                          0
# obs_name                        0
# valid_time_gmt                  0
# day_ind                         0
# temp                            0
# wx_icon                         0
# icon_extd                       0
# wx_phrase                       0
# pressure_tend                5466
# pressure_desc                5466
# dewPt                           0
# heat_index                      0
# rh                              0
# pressure                        0
# vis                             4
# wc                              8
# wdir                         1190
# wdir_cardinal                   8
# gust                         6575
# wspd                            8
# max_temp                     7490
# min_temp                     7490
# precip_total                 7695
# precip_hrly                     0
# ...

# %%
# Access raw data
bna_weather = pd.read_csv("../data/bna_weather.csv")
bna_weather.head()
# Out:
#                   Date   key        class  expire_time_gmt obs_id   obs_name  \
# 0  2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA  Nashville
# 1  2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA  Nashville
# 2  2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA  Nashville
# 3  2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA  Nashville
# 4  2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA  Nashville
#
#    valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# 0      1635745980       N    51       26  ...   OVC        NaN
# 1      1635748200       N    50       29  ...   SCT        NaN
# 2      1635749580       N    49       33  ...   CLR        NaN
# 3      1635753180       N    48       33  ...   CLR        NaN
# 4      1635756780       N    47       33  ...   CLR        NaN
#
#    primary_wave_period primary_wave_height  primary_swell_period  \
# ...

# %%
# Display columns
bna_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9739 entries, 0 to 9738
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       9739 non-null   object
#  1   key                        9739 non-null   object
#  2   class                      9739 non-null   object
#  3   expire_time_gmt            9739 non-null   int64
#  4   obs_id                     9739 non-null   object
#  5   obs_name                   9739 non-null   object
#  6   valid_time_gmt             9739 non-null   int64
#  7   day_ind                    9739 non-null   object
#  8   temp                       9739 non-null   int64
#  9   wx_icon                    9739 non-null   int64
#  10  icon_extd                  9739 non-null   int64
#  11  wx_phrase                  9739 non-null   object
#  12  pressure_tend              2885 non-null   float64
# ...

# %%
bna_weather.isna().sum()
# Out:
# Date                            0
# key                             0
# class                           0
# expire_time_gmt                 0
# obs_id                          0
# obs_name                        0
# valid_time_gmt                  0
# day_ind                         0
# temp                            0
# wx_icon                         0
# icon_extd                       0
# wx_phrase                       0
# pressure_tend                6854
# pressure_desc                6854
# dewPt                           0
# heat_index                      0
# rh                              0
# pressure                        0
# vis                             4
# wc                              8
# wdir                         1522
# wdir_cardinal                   8
# gust                         8279
# wspd                            8
# max_temp                     9378
# min_temp                     9378
# precip_total                 9636
# ...

# %%
# the columns i am interested in from the head way data.
headway_data= headway_data[['DATE','OPERATOR', 'ROUTE_ABBR', 'BLOCK_ABBR', 'TRIP_ID', 'ROUTE_DIRECTION_NAME', 'ROUTE_STOP_SEQUENCE','SCHEDULED_TIME', 'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE', 'SCHEDULED_HDWY','ACTUAL_HDWY']]
headway_data.head()
# Out:
#          DATE  OPERATOR  ROUTE_ABBR  BLOCK_ABBR  TRIP_ID ROUTE_DIRECTION_NAME  \
# 0  2021-11-01      2088           7        1704   297750          TO DOWNTOWN
# 1  2021-11-01      2088           7        1704   297750          TO DOWNTOWN
# 2  2021-11-01      2088           7        1704   297750          TO DOWNTOWN
# 3  2021-11-01      2088          50        1704   297749          TO DOWNTOWN
# 4  2021-11-01      2088          50        1704   297749          TO DOWNTOWN
#
#    ROUTE_STOP_SEQUENCE SCHEDULED_TIME ACTUAL_ARRIVAL_TIME  \
# 0                  4.0     14:10:00            13:59:21
# 1                  3.0     14:20:00            14:23:21
# 2                  2.0     14:39:00            14:36:46
# 3                  7.0     15:10:00            15:04:31
# 4                  5.0     15:27:00            15:16:59
#
#   ACTUAL_DEPARTURE_TIME  ADHERENCE  SCHEDULED_HDWY  ACTUAL_HDWY
# 0            14:12:00    -2.000000            14.0    15.983333
# ...

# %%
# the columns i am interested in from the head way data.
bna_weather = bna_weather[['Date', 'temp', 'wx_phrase']]
bna_weather.head()
# Out:
#                   Date  temp      wx_phrase
# 0  2021-11-01 00:53:00    51         Cloudy
# 1  2021-11-01 01:30:00    50  Partly Cloudy
# 2  2021-11-01 01:53:00    49           Fair
# 3  2021-11-01 02:53:00    48           Fair
# 4  2021-11-01 03:53:00    47           Fair

# %%
headway_data.BLOCK_ABBR.unique()
# Out:
# array([1704, 2200, 2201, 2202, 2210, 2211, 2300, 2301, 2302, 2303, 2310,
#        2311, 2312, 2313,  300,  301,  302,  303,  304,  305, 4101, 5000,
#        5001, 5002, 5003, 5004, 5005, 5006, 5093, 5200, 5201, 5202, 5203,
#        5204, 5205, 5206, 5210, 5211, 5212, 5213, 5214, 5215, 5216, 5217,
#        5500, 5501, 5502, 5503, 5504, 5505, 5506, 5507, 5508, 5509, 5510,
#        5511, 5512, 5590, 5600, 5601, 5602, 5603, 5604, 5605, 5606, 5607,
#        5608, 5609, 5610, 5611, 5698,  604, 6401,  700,  701,  702,  703,
#         704,  705,  706, 8401, 8405, 8601, 8604, 9302, 9975, 2390, 2391,
#        5090, 5091, 5092, 5591, 5694, 5695,  310,  311,  312, 2804,  313,
#         314,  315,  316,  317,  318, 5690, 5693, 9950, 5691, 5692, 5094,
#        5592, 5593, 5594])

# %%
headway_data.ROUTE_ABBR.unique()
# Out:
# array([ 7, 50, 22, 23,  3, 52, 55, 56])

# %%
operators = headway_data[['DATE', 'OPERATOR', 'TRIP_ID', 'ROUTE_ABBR', 'ROUTE_DIRECTION_NAME', 'ACTUAL_HDWY']]
operators.head()
# Out:
#          DATE  OPERATOR  TRIP_ID  ROUTE_ABBR ROUTE_DIRECTION_NAME  ACTUAL_HDWY
# 0  2021-11-01      2088   297750           7          TO DOWNTOWN    15.983333
# 1  2021-11-01      2088   297750           7          TO DOWNTOWN    17.333333
# 2  2021-11-01      2088   297750           7          TO DOWNTOWN          NaN
# 3  2021-11-01      2088   297749          50          TO DOWNTOWN          NaN
# 4  2021-11-01      2088   297749          50          TO DOWNTOWN          NaN

# %%
 operators['ACTUAL_HDWY'].mean()
# Out:
# 18.989718607366832

# %%
operators['ACTUAL_HDWY'].median()
# Out:
# 16.183333

# %%
operators['ACTUAL_HDWY'].mode()
# Out:
# 0    10.033333
# Name: ACTUAL_HDWY, dtype: float64

# %%
operators_avg = operators.groupby(['DATE','OPERATOR', 'ROUTE_ABBR'],  as_index=False)['ACTUAL_HDWY'].mean()

# %%
operators_avg
# Out:
#              DATE  OPERATOR  ROUTE_ABBR  ACTUAL_HDWY
# 0      2021-11-01       306          23    13.305158
# 1      2021-11-01       310          50    17.582608
# 2      2021-11-01       329          55    12.445454
# 3      2021-11-01       332          52    14.690740
# 4      2021-11-01       357          56    12.756910
# ...           ...       ...         ...          ...
# 51736  2022-11-01      2600           7    18.896428
# 51737  2022-11-01      2600          50          NaN
# 51738  2022-11-01      2603          52    21.809259
# 51739  2022-11-01      2622          55     8.560256
# 51740  2022-11-01      2630          52    14.566666
#
# [51741 rows x 4 columns]

# %%
operators_avg.columns = ['DATE','OPERATOR','ROUTE_ABBR','AVG_HDWY']

# %%
operators_avg
# Out:
#              DATE  OPERATOR  ROUTE_ABBR   AVG_HDWY
# 0      2021-11-01       306          23  13.305158
# 1      2021-11-01       310          50  17.582608
# 2      2021-11-01       329          55  12.445454
# 3      2021-11-01       332          52  14.690740
# 4      2021-11-01       357          56  12.756910
# ...           ...       ...         ...        ...
# 51736  2022-11-01      2600           7  18.896428
# 51737  2022-11-01      2600          50        NaN
# 51738  2022-11-01      2603          52  21.809259
# 51739  2022-11-01      2622          55   8.560256
# 51740  2022-11-01      2630          52  14.566666
#
# [51741 rows x 4 columns]

# %%
operators_avg['ABS_HDWY'] = operators_avg['AVG_HDWY'].abs()

# %%
operators_avg
# Out:
#              DATE  OPERATOR  ROUTE_ABBR   AVG_HDWY   ABS_HDWY
# 0      2021-11-01       306          23  13.305158  13.305158
# 1      2021-11-01       310          50  17.582608  17.582608
# 2      2021-11-01       329          55  12.445454  12.445454
# 3      2021-11-01       332          52  14.690740  14.690740
# 4      2021-11-01       357          56  12.756910  12.756910
# ...           ...       ...         ...        ...        ...
# 51736  2022-11-01      2600           7  18.896428  18.896428
# 51737  2022-11-01      2600          50        NaN        NaN
# 51738  2022-11-01      2603          52  21.809259  21.809259
# 51739  2022-11-01      2622          55   8.560256   8.560256
# 51740  2022-11-01      2630          52  14.566666  14.566666
#
# [51741 rows x 5 columns]

# %%
operators2 = operators_avg

# %%
operators2
# Out:
#              DATE  OPERATOR  ROUTE_ABBR   AVG_HDWY   ABS_HDWY
# 0      2021-11-01       306          23  13.305158  13.305158
# 1      2021-11-01       310          50  17.582608  17.582608
# 2      2021-11-01       329          55  12.445454  12.445454
# 3      2021-11-01       332          52  14.690740  14.690740
# 4      2021-11-01       357          56  12.756910  12.756910
# ...           ...       ...         ...        ...        ...
# 51736  2022-11-01      2600           7  18.896428  18.896428
# 51737  2022-11-01      2600          50        NaN        NaN
# 51738  2022-11-01      2603          52  21.809259  21.809259
# 51739  2022-11-01      2622          55   8.560256   8.560256
# 51740  2022-11-01      2630          52  14.566666  14.566666
#
# [51741 rows x 5 columns]

# %%
sns.histplot(data=headway_data, x='OPERATOR')
plt.title("adherence times by operator")
plt.xlabel('operator')
plt.ylabel('adherence times');

# %%
#Question 1 & 4

# %%
#1. How much impact does being late or too spaced out at the first stop have downstream?
#4. What is the relationship between distance or time travelled since the start of a given trip and the headway deviation? Does headway become less stable the further along the route the bus has travelled?

# %%
headway_data
# Out:
#                DATE  OPERATOR  ROUTE_ABBR  BLOCK_ABBR  TRIP_ID  \
# 0        2021-11-01      2088           7        1704   297750
# 1        2021-11-01      2088           7        1704   297750
# 2        2021-11-01      2088           7        1704   297750
# 3        2021-11-01      2088          50        1704   297749
# 4        2021-11-01      2088          50        1704   297749
# ...             ...       ...         ...         ...      ...
# 1981710  2022-11-01      2355          50        9302   329980
# 1981711  2022-11-01      1880          50        9950   330003
# 1981712  2022-11-01      1880          50        9950   330003
# 1981713  2022-11-01      1922          56        9975   330011
# 1981714  2022-11-01      1922          56        9975   330011
#
#         ROUTE_DIRECTION_NAME  ROUTE_STOP_SEQUENCE SCHEDULED_TIME  \
# 0                TO DOWNTOWN                  4.0     14:10:00
# 1                TO DOWNTOWN                  3.0     14:20:00
# ...

# %%
headway_data2 = headway_data.dropna(how='any', axis=0)
headway_data2
# Out:
#                DATE  OPERATOR  ROUTE_ABBR  BLOCK_ABBR  TRIP_ID  \
# 0        2021-11-01      2088           7        1704   297750
# 1        2021-11-01      2088           7        1704   297750
# 12       2021-11-01      1352          22        2200   298128
# 13       2021-11-01      1352          22        2200   298128
# 14       2021-11-01      1352          22        2200   298128
# ...             ...       ...         ...         ...      ...
# 1981695  2022-11-01       375           7         706   329461
# 1981696  2022-11-01       375           7         706   329461
# 1981698  2022-11-01       375           7         706   329459
# 1981699  2022-11-01       375           7         706   329459
# 1981711  2022-11-01      1880          50        9950   330003
#
#         ROUTE_DIRECTION_NAME  ROUTE_STOP_SEQUENCE SCHEDULED_TIME  \
# 0                TO DOWNTOWN                  4.0     14:10:00
# 1                TO DOWNTOWN                  3.0     14:20:00
# ...

# %%
headway_data2.columns = ['date', 'rte_abbr', 'blk_abbr', 'operator', 'trip_id', 'rte_dir_name', 'rte_stop_seq', 'schd_time', 'act_arrvl_time', 'act_depart', 'adher', 'schd_hdwy', 'act_hdwy']

# %%
headway_data2.head()
# Out:
#           date  rte_abbr  blk_abbr  operator  trip_id rte_dir_name  \
# 0   2021-11-01      2088         7      1704   297750  TO DOWNTOWN
# 1   2021-11-01      2088         7      1704   297750  TO DOWNTOWN
# 12  2021-11-01      1352        22      2200   298128  TO DOWNTOWN
# 13  2021-11-01      1352        22      2200   298128  TO DOWNTOWN
# 14  2021-11-01      1352        22      2200   298128  TO DOWNTOWN
#
#     rte_stop_seq   schd_time act_arrvl_time  act_depart     adher  schd_hdwy  \
# 0            4.0  14:10:00       13:59:21    14:12:00   -2.000000       14.0
# 1            3.0  14:20:00       14:23:21    14:23:21   -3.350000       14.0
# 12          15.0  05:42:00       05:33:39    05:43:03   -1.050000       35.0
# 13          11.0  05:46:00       05:48:15    05:48:15   -2.250000       35.0
# 14           6.0  05:54:00       05:54:23    05:54:23   -0.383333       15.0
#
#      act_hdwy
# 0   15.983333
# 1   17.333333
# 12  34.633333
# 13  35.866666
# 14  13.983333

# %%
#BUCKET MONTHS
#example from reddit 
from collections import defaultdict

def partition(seq, key):
    d = defaultdict(list)
    for x in seq:
        d[key(x)].append(x)
    return d
