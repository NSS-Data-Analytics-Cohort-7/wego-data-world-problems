# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather_2022= pd.read_csv('../data/bna_2022.csv')

# %%
weather_2022.head()
# Out:
#     key        class  expire_time_gmt obs_id   obs_name  valid_time_gmt  \
# 0  KBNA  observation       1641027180   KBNA  Nashville      1641019980
# 1  KBNA  observation       1641030780   KBNA  Nashville      1641023580
# 2  KBNA  observation       1641034380   KBNA  Nashville      1641027180
# 3  KBNA  observation       1641037980   KBNA  Nashville      1641030780
# 4  KBNA  observation       1641041580   KBNA  Nashville      1641034380
#
#   day_ind  temp  wx_icon  icon_extd  ... clds  water_temp primary_wave_period  \
# 0       N    71       26       2600  ...  OVC         NaN                 NaN
# 1       N    72       26       2600  ...  OVC         NaN                 NaN
# 2       N    73       26       2600  ...  OVC         NaN                 NaN
# 3       N    73       26       2600  ...  OVC         NaN                 NaN
# 4       N    73       26       2600  ...  OVC         NaN                 NaN
#
# ...

# %%
weather = pd.read_csv('../data/bna_weather.csv')

# %%
weather.head()
# Out:
#                   Date   key        class  expire_time_gmt obs_id   obs_name  \
# 0  2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA  Nashville
# 1  2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA  Nashville
# 2  2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA  Nashville
# 3  2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA  Nashville
# 4  2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA  Nashville
#
#    valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# 0      1635745980       N    51       26  ...   OVC        NaN
# 1      1635748200       N    50       29  ...   SCT        NaN
# 2      1635749580       N    49       33  ...   CLR        NaN
# 3      1635753180       N    48       33  ...   CLR        NaN
# 4      1635756780       N    47       33  ...   CLR        NaN
#
#    primary_wave_period primary_wave_height  primary_swell_period  \
# ...

# %%
headway = pd.read_csv('../data/Headway Data.csv')

# %%
headway.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
# 4    120211101             1      76447168  2021-11-01          50
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# 0        1704      2088   297750            0          TO DOWNTOWN  ...
# 1        1704      2088   297750            0          TO DOWNTOWN  ...
# 2        1704      2088   297750            0          TO DOWNTOWN  ...
# 3        1704      2088   297749            0          TO DOWNTOWN  ...
# 4        1704      2088   297749            0          TO DOWNTOWN  ...
#
#   ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# ...

# %%
weather.isna().sum()
# Out:
# Date                            0
# key                             0
# class                           0
# expire_time_gmt                 0
# obs_id                          0
# obs_name                        0
# valid_time_gmt                  0
# day_ind                         0
# temp                            0
# wx_icon                         0
# icon_extd                       0
# wx_phrase                       0
# pressure_tend                6854
# pressure_desc                6854
# dewPt                           0
# heat_index                      0
# rh                              0
# pressure                        0
# vis                             4
# wc                              8
# wdir                         1522
# wdir_cardinal                   8
# gust                         8279
# wspd                            8
# max_temp                     9378
# min_temp                     9378
# precip_total                 9636
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9739 entries, 0 to 9738
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       9739 non-null   object
#  1   key                        9739 non-null   object
#  2   class                      9739 non-null   object
#  3   expire_time_gmt            9739 non-null   int64
#  4   obs_id                     9739 non-null   object
#  5   obs_name                   9739 non-null   object
#  6   valid_time_gmt             9739 non-null   int64
#  7   day_ind                    9739 non-null   object
#  8   temp                       9739 non-null   int64
#  9   wx_icon                    9739 non-null   int64
#  10  icon_extd                  9739 non-null   int64
#  11  wx_phrase                  9739 non-null   object
#  12  pressure_tend              2885 non-null   float64
# ...

# %%
headway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1981715 entries, 0 to 1981714
# Data columns (total 30 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   CALENDAR_ID                int64
#  1   SERVICE_ABBR               int64
#  2   ADHERENCE_ID               int64
#  3   DATE                       object
#  4   ROUTE_ABBR                 int64
#  5   BLOCK_ABBR                 int64
#  6   OPERATOR                   int64
#  7   TRIP_ID                    int64
#  8   OVERLOAD_ID                int64
#  9   ROUTE_DIRECTION_NAME       object
#  10  TIME_POINT_ABBR            object
#  11  ROUTE_STOP_SEQUENCE        float64
#  12  TRIP_EDGE                  int64
#  13  LATITUDE                   float64
#  14  LONGITUDE                  float64
#  15  SCHEDULED_TIME             object
#  16  ACTUAL_ARRIVAL_TIME        object
#  17  ACTUAL_DEPARTURE_TIME      object
#  18  ADHERENCE                  float64
# ...

# %%
headway.isnull().sum() / headway.shape[0] * 100
# Out:
# CALENDAR_ID                   0.000000
# SERVICE_ABBR                  0.000000
# ADHERENCE_ID                  0.000000
# DATE                          0.000000
# ROUTE_ABBR                    0.000000
# BLOCK_ABBR                    0.000000
# OPERATOR                      0.000000
# TRIP_ID                       0.000000
# OVERLOAD_ID                   0.000000
# ROUTE_DIRECTION_NAME          0.000000
# TIME_POINT_ABBR               0.000000
# ROUTE_STOP_SEQUENCE           0.002069
# TRIP_EDGE                     0.000000
# LATITUDE                      0.000000
# LONGITUDE                     0.000000
# SCHEDULED_TIME                0.000000
# ACTUAL_ARRIVAL_TIME           2.744239
# ACTUAL_DEPARTURE_TIME         2.746611
# ADHERENCE                     2.746611
# SCHEDULED_HDWY               21.814136
# ACTUAL_HDWY                  23.909795
# HDWY_DEV                     23.937246
# ADJUSTED_EARLY_COUNT          0.000000
# ADJUSTED_LATE_COUNT           0.000000
# ...

# %%
headway.describe()
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID    ROUTE_ABBR    BLOCK_ABBR  \
# count  1.981715e+06  1.981715e+06  1.981715e+06  1.981715e+06  1.981715e+06
# mean   1.202191e+08  1.301276e+00  8.440206e+07  3.933449e+01  3.947508e+03
# std    3.423559e+03  6.398457e-01  4.330643e+06  1.969928e+01  1.973956e+03
# min    1.202111e+08  1.000000e+00  7.644716e+07  3.000000e+00  3.000000e+02
# 25%    1.202202e+08  1.000000e+00  8.075122e+07  2.300000e+01  2.301000e+03
# 50%    1.202205e+08  1.000000e+00  8.470092e+07  5.200000e+01  5.200000e+03
# 75%    1.202208e+08  1.000000e+00  8.828194e+07  5.500000e+01  5.506000e+03
# max    1.202211e+08  3.000000e+00  9.109076e+07  5.600000e+01  9.975000e+03
#
#            OPERATOR       TRIP_ID   OVERLOAD_ID  ROUTE_STOP_SEQUENCE  \
# count  1.981715e+06  1.981715e+06  1.981715e+06         1.981674e+06
# mean   1.635251e+03  3.111437e+05  9.984281e-03         7.122218e+00
# std    6.375643e+02  7.312918e+03  1.291578e-01         3.828157e+00
# ...

# %%
headway.STOP_CANCELLED.value_counts()
# Out:
# 0    1931137
# 1      50578
# Name: STOP_CANCELLED, dtype: int64

# %%
headway.ROUTE_DIRECTION_NAME.value_counts()
# Out:
# FROM DOWNTOWN    1047952
# TO DOWNTOWN       933763
# Name: ROUTE_DIRECTION_NAME, dtype: int64

# %%
weather.temp.value_counts()
# Out:
# 73     261
# 77     244
# 74     224
# 75     222
# 76     216
#       ...
# 99       5
# 14       4
# 16       3
# 15       3
# 100      2
# Name: temp, Length: 87, dtype: int64

# %%
plt.hist(weather['temp'], bins = 10)
# Out:
# (array([  97.,  456.,  813., 1086., 1155., 1637., 1785., 1516.,  958.,
#          236.]),
#  array([ 14. ,  22.6,  31.2,  39.8,  48.4,  57. ,  65.6,  74.2,  82.8,
#          91.4, 100. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(weather['heat_index'])
# Out:
# (array([ 119.,  534.,  917., 1336., 1386., 1692., 1836., 1261.,  518.,
#          140.]),
#  array([ 14. ,  23.3,  32.6,  41.9,  51.2,  60.5,  69.8,  79.1,  88.4,
#          97.7, 107. ]),
#  <BarContainer object of 10 artists>)

# %%
weather['Date'] = weather['Date'].str[:9]

# %%
weather.head()
# Out:
#         Date   key        class  expire_time_gmt obs_id   obs_name  \
# 0  2021-11-0  KBNA  observation       1635753180   KBNA  Nashville
# 1  2021-11-0  KBNA  observation       1635755400   KBNA  Nashville
# 2  2021-11-0  KBNA  observation       1635756780   KBNA  Nashville
# 3  2021-11-0  KBNA  observation       1635760380   KBNA  Nashville
# 4  2021-11-0  KBNA  observation       1635763980   KBNA  Nashville
#
#    valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# 0      1635745980       N    51       26  ...   OVC        NaN
# 1      1635748200       N    50       29  ...   SCT        NaN
# 2      1635749580       N    49       33  ...   CLR        NaN
# 3      1635753180       N    48       33  ...   CLR        NaN
# 4      1635756780       N    47       33  ...   CLR        NaN
#
#    primary_wave_period primary_wave_height  primary_swell_period  \
# 0                  NaN                 NaN                   NaN
# ...

# %%
headway = headway.rename(columns={'DATE': 'Date'})

# %%
merged_data = pd.merge(headway, weather, on = 'Date', how = 'outer')

# %%
merged_data.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        Date  ROUTE_ABBR  \
# 0  120211101.0           1.0    76447164.0  2021-11-01         7.0
# 1  120211101.0           1.0    76447165.0  2021-11-01         7.0
# 2  120211101.0           1.0    76447166.0  2021-11-01         7.0
# 3  120211101.0           1.0    76447167.0  2021-11-01        50.0
# 4  120211101.0           1.0    76447168.0  2021-11-01        50.0
#
#    BLOCK_ABBR  OPERATOR   TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ... clds  \
# 0      1704.0    2088.0  297750.0          0.0          TO DOWNTOWN  ...  NaN
# 1      1704.0    2088.0  297750.0          0.0          TO DOWNTOWN  ...  NaN
# 2      1704.0    2088.0  297750.0          0.0          TO DOWNTOWN  ...  NaN
# 3      1704.0    2088.0  297749.0          0.0          TO DOWNTOWN  ...  NaN
# 4      1704.0    2088.0  297749.0          0.0          TO DOWNTOWN  ...  NaN
#
#    water_temp  primary_wave_period  primary_wave_height  primary_swell_period  \
# ...

# %%
operators = headway[['OPERATOR','SCHEDULED_HDWY','ACTUAL_HDWY','HDWY_DEV','ACTUAL_ARRIVAL_TIME','ACTUAL_DEPARTURE_TIME']]

# %%
operators.head()
# Out:
#    OPERATOR  SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV ACTUAL_ARRIVAL_TIME  \
# 0      2088            14.0    15.983333  1.983333          13:59:21
# 1      2088            14.0    17.333333  3.333333          14:23:21
# 2      2088             NaN          NaN       NaN          14:36:46
# 3      2088             NaN          NaN       NaN          15:04:31
# 4      2088             NaN          NaN       NaN          15:16:59
#
#   ACTUAL_DEPARTURE_TIME
# 0            14:12:00
# 1            14:23:21
# 2            14:59:11
# 3            15:10:17
# 4            15:16:59

# %%
distance = headway[['ROUTE_STOP_SEQUENCE','SCHEDULED_HDWY','ACTUAL_HDWY','HDWY_DEV','ACTUAL_ARRIVAL_TIME','ACTUAL_DEPARTURE_TIME','TRIP_EDGE','ADHERENCE']]

# %%
distance.head()
# Out:
#    ROUTE_STOP_SEQUENCE  SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV  \
# 0                  4.0            14.0    15.983333  1.983333
# 1                  3.0            14.0    17.333333  3.333333
# 2                  2.0             NaN          NaN       NaN
# 3                  7.0             NaN          NaN       NaN
# 4                  5.0             NaN          NaN       NaN
#
#   ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  TRIP_EDGE  ADHERENCE
# 0          13:59:21              14:12:00            1  -2.000000
# 1          14:23:21              14:23:21            0  -3.350000
# 2          14:36:46              14:59:11            2 -20.183333
# 3          15:04:31              15:10:17            1  -0.283333
# 4          15:16:59              15:16:59            2  10.016666

# %%
distance_grouped = distance.groupby(['ROUTE_STOP_SEQUENCE'])['ACTUAL_HDWY'].mean()

# %%
distance_grouped.head()
# Out:
# ROUTE_STOP_SEQUENCE
# 1.0    18.480995
# 2.0    18.457371
# 3.0    18.885792
# 4.0    18.847871
# 5.0    17.584520
# Name: ACTUAL_HDWY, dtype: float64

# %%
plt.plot(distance_grouped)
plt.xlabel("Route Stop Sequence")
plt.ylabel("Average Actual Headway")
plt.show()

# %%
trip_edge =distance.groupby(['TRIP_EDGE'])['ADHERENCE'].mean()

# %%
trip_edge
# Out:
# TRIP_EDGE
# 0   -2.794984
# 1   -1.936145
# 2   -0.572849
# Name: ADHERENCE, dtype: float64

# %%
trip_edge = trip_edge.drop([0])

# %%
trip_edge
# Out:
# TRIP_EDGE
# 1   -1.936145
# 2   -0.572849
# Name: ADHERENCE, dtype: float64

# %%
df = pd.DataFrame({'lab':['Trip Start', 'Trip end'], 'val':[-1.936145, -0.572849]})
ax = df.plot.barh(x='lab', y='val', rot=0, color = 'purple')
ax.invert_xaxis()
ax.get_legend().remove()
sns.color_palette("rocket")
plt.show()

# %%
directions = headway[['ROUTE_DIRECTION_NAME','SCHEDULED_TIME','ACTUAL_ARRIVAL_TIME','ACTUAL_DEPARTURE_TIME','ADHERENCE']]

# %%
display(directions)
# Out:
#         ROUTE_DIRECTION_NAME SCHEDULED_TIME ACTUAL_ARRIVAL_TIME  \
# 0                TO DOWNTOWN     14:10:00            13:59:21
# 1                TO DOWNTOWN     14:20:00            14:23:21
# 2                TO DOWNTOWN     14:39:00            14:36:46
# 3                TO DOWNTOWN     15:10:00            15:04:31
# 4                TO DOWNTOWN     15:27:00            15:16:59
# ...                      ...            ...                 ...
# 1981710          TO DOWNTOWN     15:18:00            15:19:43
# 1981711          TO DOWNTOWN     15:20:00            14:57:12
# 1981712          TO DOWNTOWN     15:37:00            15:10:16
# 1981713          TO DOWNTOWN     15:20:00            14:59:40
# 1981714          TO DOWNTOWN     15:30:00            15:26:05
#
#         ACTUAL_DEPARTURE_TIME  ADHERENCE
# 0                  14:12:00    -2.000000
# 1                  14:23:21    -3.350000
# 2                  14:59:11   -20.183333
# 3                  15:10:17    -0.283333
# ...
